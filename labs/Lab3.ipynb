# %% [markdown]
# # Data: Past, Present, Future
# ## Exploratory Data Analysis: fun with `pandas`

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
plt.style.use("ggplot")

# %matplotlib notebook

# %% [markdown]
# A data set for the Academy's consideration:
#
# https://github.com/deedy/gradcafe_data
#
# Let's use:
#
# https://github.com/deedy/gradcafe_data/blob/master/all_uisc_clean.csv?raw=true

# %% [markdown]
# ### Discussion

# %% [markdown]
# **How was this data produced?**

# %% [markdown]
# **What assumptions does it make?**

# %% [markdown]
# **What purpose was this data collected for?**

# %% [markdown]
# **What is being approximated?**

# %% [markdown]
# ### Back to the Activity

# %% [markdown]
# 'Cuz I'm nice, I'm gonna give you the names of the columns

# %%
labels = [
    "row_id", "uni_name", "major", "degree", "season", "decision",
    "decision_method", "decision_date", "decision_timestamp", "ugrad_gpa",
    "gre_verbal","gre_quant","gre_writing", "is_new_gre", "gre_subject",
    "status", "post_date", "post_timestamp", "comments"
]

# %% [markdown]
# We import directly from the web without having to download using `wget`.

# %%
gre = pd.read_csv(
    "https://github.com/deedy/gradcafe_data/blob/master/all_uisc_clean.csv?raw=true",
    sep=",",
    names=labels
)
# Out:
# /Users/suhang/anaconda/envs/future/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (5,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Note this throws a warning. Does anyone know what it means?

# %% [markdown]
# Let's take a looksee...

# %%
gre.head()
# Out:
#    row_id                                 uni_name  \
# 0       0  University Of Southern California (USC)
# 1       1                    Vanderbilt University
# 2       2                 University Of Pittsburgh
# 3       3                         Tufts University
# 4       4                  University Of Edinburgh
#
#                           major degree season  decision decision_method  \
# 0        Ms. Green Technologies     MS    S16  Accepted          E-mail
# 1  Education: Special Education     MS    F16     Other           Other
# 2                  Public Heath     MS    F16  Accepted          E-mail
# 3              Computer Science    PhD    S16  Accepted          E-mail
# 4           Theoretical Physics     MS    F16  Accepted         Website
#
#     decision_date  decision_timestamp  ugrad_gpa  gre_verbal  gre_quant  \
# 0   (5, 11, 2015)        1.446700e+09        NaN         NaN        NaN
# 1             NaN                 NaN        NaN         NaN        NaN
# 2  (16, 11, 2015)        1.447650e+09        NaN         NaN        NaN
# 3  (16, 11, 2015)        1.447650e+09        3.6       166.0      163.0
# 4  (16, 11, 2015)        1.447650e+09        NaN         NaN        NaN
#
#    gre_writing is_new_gre  gre_subject         status       post_date  \
# 0          NaN        NaN          NaN       American  (17, 11, 2015)
# 1          NaN        NaN          NaN       American  (17, 11, 2015)
# 2          NaN        NaN          NaN       American  (16, 11, 2015)
# 3          4.5       True          NaN       American  (16, 11, 2015)
# 4          NaN        NaN          NaN  International  (16, 11, 2015)
#
#    post_timestamp                                           comments
# 0      1447736400  Hard work has paid off. Financial aid offer ha...
# 1      1447736400  Hello everyone! I am wondering if I even have ...
# 2      1447650000          Short email acceptance. Letter to follow.
# 3      1447650000  Met with professor beforehand. 1 year academic...
# 4      1447650000  The time when I applied for the course was 1st...

# %% [markdown]
# Note that you can show more rows or less rows by adding a number to head, e.g., `gre.head(10)`. What does the inclusion of this particular information tell us about the assumptions of this data set? (Has anyone ever been to the grad cafe?)

# %% [markdown]
# Now lets look at an individual column similar to the way we did last week.

# %%
gre["ugrad_gpa"]
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3         3.60
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8         3.97
# 9          NaN
# 10         NaN
# 11        4.00
# 12        4.00
# 13        4.00
# 14        4.00
# 15         NaN
# 16        3.56
# 17         NaN
# 18         NaN
# 19         NaN
# 20        2.70
# 21         NaN
# 22         NaN
# 23        3.50
# 24         NaN
# 25        3.50
# 26        3.50
# 27        3.50
# 28         NaN
# 29         NaN
#           ...
# 345273     NaN
# 345274     NaN
# 345275     NaN
# 345276     NaN
# 345277     NaN
# 345278     NaN
# 345279     NaN
# 345280     NaN
# 345281     NaN
# 345282     NaN
# 345283     NaN
# 345284     NaN
# 345285     NaN
# 345286     NaN
# 345287     NaN
# 345288     NaN
# 345289     NaN
# 345290     NaN
# 345291     NaN
# 345292     NaN
# 345293     NaN
# 345294     NaN
# 345295     NaN
# 345296     NaN
# 345297     NaN
# 345298     NaN
# 345299     NaN
# 345300     NaN
# 345301     NaN
# 345302     NaN
# Name: ugrad_gpa, Length: 345303, dtype: float64

# %% [markdown]
# What new information do we learn from this? What should concern us?

# %%
gre['ugrad_gpa'].mean()
# Out:
# 3.684991738201731

# %% [markdown]
# Recall the `describe()` from lab 2. Now we get to properly use it!

# %%
gre['ugrad_gpa'].describe()
# Out:
# count    74439.000000
# mean         3.684992
# std          0.448914
# min          0.250000
# 25%          3.500000
# 50%          3.720000
# 75%          3.890000
# max          9.990000
# Name: ugrad_gpa, dtype: float64

# %% [markdown]
# What might we learn from considering these past three code blocks? Are there any obvious biases?

# %%
gre.describe(include="all")
# Out:
#                row_id             uni_name             major  degree  season  \
# count   345303.000000               345169            345296  345303  287034
# unique            NaN                 4535             23669       7      15
# top               NaN  Columbia University  Computer Science     PhD     F14
# freq              NaN                10901             19278  218813   57209
# mean    172651.000000                  NaN               NaN     NaN     NaN
# std      99680.534338                  NaN               NaN     NaN     NaN
# min          0.000000                  NaN               NaN     NaN     NaN
# 25%      86325.500000                  NaN               NaN     NaN     NaN
# 50%     172651.000000                  NaN               NaN     NaN     NaN
# 75%     258976.500000                  NaN               NaN     NaN     NaN
# max     345302.000000                  NaN               NaN     NaN     NaN
#
#         decision decision_method  decision_date  decision_timestamp  \
# count     344808          344817         345088        3.450880e+05
# unique         5               5           2859                 NaN
# top     Accepted          E-mail  (28, 2, 2014)                 NaN
# freq      143977          228083           1258                 NaN
# mean         NaN             NaN            NaN        1.331650e+09
# std          NaN             NaN            NaN        3.102188e+08
# min          NaN             NaN            NaN        4.013424e+08
# 25%          NaN             NaN            NaN        1.269317e+09
# 50%          NaN             NaN            NaN        1.333339e+09
# 75%          NaN             NaN            NaN        1.393823e+09
# max          NaN             NaN            NaN        1.720000e+11
#
#            ugrad_gpa    gre_verbal     gre_quant   gre_writing is_new_gre  \
# count   74439.000000  80527.000000  80527.000000  77349.000000      80527
# unique           NaN           NaN           NaN           NaN          2
# top              NaN           NaN           NaN           NaN       True
# freq             NaN           NaN           NaN           NaN      56775
# mean        3.684992    296.369826    327.516609      4.271339        NaN
# std         0.448914    221.193776    263.184333      0.818622        NaN
# min         0.250000    130.000000    130.000000      0.300000        NaN
# 25%         3.500000    156.000000    158.000000      3.500000        NaN
# 50%         3.720000    163.000000    166.000000      4.500000        NaN
# 75%         3.890000    520.000000    630.000000      5.000000        NaN
# max         9.990000    800.000000    800.000000      6.000000        NaN
#
#          gre_subject    status     post_date  post_timestamp comments
# count   11673.000000    320888        345303    3.453030e+05   209941
# unique           NaN         4          2756             NaN   189902
# top              NaN  American  (3, 3, 2015)             NaN       :(
# freq             NaN    180521          1221             NaN      552
# mean      781.520603       NaN           NaN    1.331155e+09      NaN
# std       121.167891       NaN           NaN    7.489521e+07      NaN
# min       200.000000       NaN           NaN    1.139375e+09      NaN
# 25%       690.000000       NaN           NaN    1.269403e+09      NaN
# 50%       780.000000       NaN           NaN    1.333512e+09      NaN
# 75%       870.000000       NaN           NaN    1.393996e+09      NaN
# max       990.000000       NaN           NaN    1.447909e+09      NaN

# %% [markdown]
# ## Doing snazzy stuff with `groupby`
# What do the following three functions do?

# %%
gre.groupby(by='decision').mean()
# Out:
#                     row_id  decision_timestamp  ugrad_gpa  gre_verbal  \
# decision
# Accepted     168655.386652        1.332546e+09   3.693544  295.214577
# Interview    167488.366358        1.350378e+09   3.683913  281.851587
# Other        169011.538583        1.337147e+09   3.683160  302.763473
# Rejected     180512.134516        1.325107e+09   3.673614  303.231495
# Wait listed  160337.083868        1.340868e+09   3.683369  277.112044
#
#               gre_quant  gre_writing  gre_subject  post_timestamp
# decision
# Accepted     326.079284     4.296000   794.194650    1.332348e+09
# Interview    302.986571     4.474391   752.688728    1.350548e+09
# Other        332.965070     4.263446   768.022388    1.337186e+09
# Rejected     338.519840     4.184256   775.928571    1.323927e+09
# Wait listed  296.915627     4.358722   764.065934    1.341097e+09

# %%
gre.groupby(by="uni_name").mean()
# Out:
#                                                            row_id  \
# uni_name
# A.T. Still University                                47733.034483
# AA School Of Architecture                           316128.000000
# AAUW Fellowship                                     278406.000000
# ADH Geneva Academy Of International Humanitaria...  281000.000000
# ALL                                                 341891.000000
# ALL University                                      187592.000000
# AMNH Richard Gilder Graduate School                 293831.500000
# ARIZONA STATE UNIV                                   76995.000000
# ASEE SMART                                          317667.666667
# AT&T Labs Fellowship Program (ALFP)                 325517.000000
# Aalto University                                     87306.333333
# Aarhus School Of Architecture                       306813.000000
# Abdus Salam International Centre for Theoretica...  272866.500000
# Aberystwyth University                               93791.250000
# Abilene Christian                                   302034.333333
# Abilene Christian University                         69373.354167
# Acadia                                              330916.000000
# Acadia University                                   232856.000000
# Addis Ababa University                              127003.000000
# Adelhpi University (Derner Institute)               147443.000000
# Adelhpi University/ C.W. Post                       134809.000000
# Adelphi Univ.                                       156558.800000
# Adelphi University                                  189536.039773
# Adler                                               335300.000000
# Adler School Of Professional Psychology             310372.451613
# Adler School Of Professional Psychology/Adler U...   23851.000000
# Adler University                                     28432.000000
# Adler University (Chicago)                           29846.000000
# Adler University (Vancouver)                          6983.000000
# Adler University, Vancouver                          18449.000000
# ...                                                           ...
# Wycliffe College                                    303154.000000
# Wycliffe College At University Of Toronto            21619.000000
# Wyoming                                             336600.500000
# Wyoming University                                   56314.000000
# Xavier University                                    63181.212121
# Xiamen University                                   178678.000000
# Xxxx University                                      43520.000000
# Xxxxxxx University                                   43504.000000
# Yale Uni                                             41124.000000
# Yale Univ                                            85028.000000
# Yale University                                     224867.762427
# Yalel Academy                                       283851.000000
# Yanshan University                                  158913.000000
# Yeshiva University                                  187732.980100
# Yildiz Technical University                          78673.000000
# Yokohama National University                        202375.000000
# Yonsei University                                   265530.000000
# York Univ. (Toronto)                                167643.000000
# York University                                     130228.900627
# York Univetsit                                       11557.000000
# Youngstown State University                         140111.500000
# Yuan Ze University                                  260664.000000
# ZIBI Graduate School Berlin                         278325.000000
# Zarif University                                    119196.000000
# Zhejiang University                                 226497.000000
# Zhejiang University Of Technology                   100139.000000
# Zhengzhou University                                 87738.000000
# Zurich Graduate School In Mathematics               299186.750000
# Zurich Life Sciences                                320966.000000
# Zurich School Of Economics                          311508.000000
#
#                                                     decision_timestamp  \
# uni_name
# A.T. Still University                                     1.401796e+09
# AA School Of Architecture                                 1.331183e+09
# AAUW Fellowship                                           1.334549e+09
# ADH Geneva Academy Of International Humanitaria...        1.301976e+09
# ALL                                                       1.303963e+09
# ALL University                                            1.297314e+09
# AMNH Richard Gilder Graduate School                       1.424320e+09
# ARIZONA STATE UNIV                                        1.392008e+09
# ASEE SMART                                                1.324371e+09
# AT&T Labs Fellowship Program (ALFP)                       1.266901e+09
# Aalto University                                          1.366315e+09
# Aarhus School Of Architecture                             1.366085e+09
# Abdus Salam International Centre for Theoretica...        1.425616e+09
# Aberystwyth University                                    1.370990e+09
# Abilene Christian                                         1.383539e+09
# Abilene Christian University                              1.383268e+09
# Acadia                                                    1.425532e+09
# Acadia University                                         1.236229e+09
# Addis Ababa University                                    1.334290e+09
# Adelhpi University (Derner Institute)                     1.329592e+09
# Adelhpi University/ C.W. Post                             1.331096e+09
# Adelphi Univ.                                             1.311636e+09
# Adelphi University                                        1.420793e+09
# Adler                                                     1.392872e+09
# Adler School Of Professional Psychology                   1.361104e+09
# Adler School Of Professional Psychology/Adler U...        1.425013e+09
# Adler University                                          1.424236e+09
# Adler University (Chicago)                                1.419052e+09
# Adler University (Vancouver)                              1.427947e+09
# Adler University, Vancouver                               1.424927e+09
# ...                                                                ...
# Wycliffe College                                          1.393218e+09
# Wycliffe College At University Of Toronto                 1.425359e+09
# Wyoming                                                   1.375852e+09
# Wyoming University                                        1.395029e+09
# Xavier University                                         1.391103e+09
# Xiamen University                                         1.298869e+09
# Xxxx University                                           1.412654e+09
# Xxxxxxx University                                        1.412741e+09
# Yale Uni                                                  1.421298e+09
# Yale Univ                                                 1.389330e+09
# Yale University                                           1.300315e+09
# Yalel Academy                                             1.268456e+09
# Yanshan University                                        1.322456e+09
# Yeshiva University                                        1.351612e+09
# Yildiz Technical University                               1.391663e+09
# Yokohama National University                              1.268543e+09
# Yonsei University                                         1.167109e+09
# York Univ. (Toronto)                                      1.300680e+09
# York University                                           1.334847e+09
# York Univetsit                                            1.426824e+09
# Youngstown State University                               1.330922e+09
# Yuan Ze University                                        1.174018e+09
# ZIBI Graduate School Berlin                               1.355461e+09
# Zarif University                                          1.359695e+09
# Zhejiang University                                       1.250701e+09
# Zhejiang University Of Technology                         1.363061e+09
# Zhengzhou University                                      1.367381e+09
# Zurich Graduate School In Mathematics                     1.401037e+09
# Zurich Life Sciences                                      1.292000e+09
# Zurich School Of Economics                                1.361509e+09
#
#                                                     ugrad_gpa  gre_verbal  \
# uni_name
# A.T. Still University                                3.302000  152.600000
# AA School Of Architecture                                 NaN         NaN
# AAUW Fellowship                                           NaN         NaN
# ADH Geneva Academy Of International Humanitaria...        NaN         NaN
# ALL                                                       NaN         NaN
# ALL University                                            NaN         NaN
# AMNH Richard Gilder Graduate School                       NaN         NaN
# ARIZONA STATE UNIV                                   3.720000  152.500000
# ASEE SMART                                           3.650000  565.000000
# AT&T Labs Fellowship Program (ALFP)                       NaN         NaN
# Aalto University                                     3.610000  334.666667
# Aarhus School Of Architecture                             NaN         NaN
# Abdus Salam International Centre for Theoretica...        NaN         NaN
# Aberystwyth University                               3.800000  160.000000
# Abilene Christian                                    3.820000  157.000000
# Abilene Christian University                         3.491818  195.250000
# Acadia                                                    NaN         NaN
# Acadia University                                         NaN         NaN
# Addis Ababa University                                    NaN         NaN
# Adelhpi University (Derner Institute)                4.000000  690.000000
# Adelhpi University/ C.W. Post                             NaN         NaN
# Adelphi Univ.                                        3.510000  147.000000
# Adelphi University                                   3.706596  238.074468
# Adler                                                3.710000  161.000000
# Adler School Of Professional Psychology              3.660000  290.666667
# Adler School Of Professional Psychology/Adler U...   3.710000  148.000000
# Adler University                                     3.640000  157.500000
# Adler University (Chicago)                                NaN         NaN
# Adler University (Vancouver)                              NaN         NaN
# Adler University, Vancouver                          2.230000  152.000000
# ...                                                       ...         ...
# Wycliffe College                                          NaN         NaN
# Wycliffe College At University Of Toronto            3.900000  161.000000
# Wyoming                                                   NaN         NaN
# Wyoming University                                   3.650000         NaN
# Xavier University                                    3.676667  155.000000
# Xiamen University                                         NaN         NaN
# Xxxx University                                           NaN         NaN
# Xxxxxxx University                                        NaN         NaN
# Yale Uni                                                  NaN         NaN
# Yale Univ                                            3.890000  640.000000
# Yale University                                      3.765719  372.123396
# Yalel Academy                                             NaN         NaN
# Yanshan University                                        NaN         NaN
# Yeshiva University                                   3.688205  296.780488
# Yildiz Technical University                          3.890000  160.000000
# Yokohama National University                              NaN         NaN
# Yonsei University                                         NaN         NaN
# York Univ. (Toronto)                                      NaN         NaN
# York University                                      3.632523  367.128000
# York Univetsit                                            NaN         NaN
# Youngstown State University                          3.500000  650.000000
# Yuan Ze University                                        NaN         NaN
# ZIBI Graduate School Berlin                               NaN         NaN
# Zarif University                                          NaN         NaN
# Zhejiang University                                       NaN         NaN
# Zhejiang University Of Technology                    3.700000  168.000000
# Zhengzhou University                                 3.200000  140.000000
# Zurich Graduate School In Mathematics                     NaN         NaN
# Zurich Life Sciences                                 3.260000  560.000000
# Zurich School Of Economics                                NaN         NaN
#
#                                                      gre_quant  gre_writing  \
# uni_name
# A.T. Still University                               145.200000     4.200000
# AA School Of Architecture                                  NaN          NaN
# AAUW Fellowship                                            NaN          NaN
# ADH Geneva Academy Of International Humanitaria...         NaN          NaN
# ALL                                                        NaN          NaN
# ALL University                                             NaN          NaN
# AMNH Richard Gilder Graduate School                        NaN          NaN
# ARIZONA STATE UNIV                                  153.500000     3.250000
# ASEE SMART                                          765.000000     4.500000
# AT&T Labs Fellowship Program (ALFP)                        NaN          NaN
# Aalto University                                    376.333333     3.833333
# Aarhus School Of Architecture                              NaN          NaN
# Abdus Salam International Centre for Theoretica...         NaN          NaN
# Aberystwyth University                              151.000000     3.500000
# Abilene Christian                                   152.000000     4.500000
# Abilene Christian University                        175.666667     4.318182
# Acadia                                                     NaN          NaN
# Acadia University                                          NaN          NaN
# Addis Ababa University                                     NaN          NaN
# Adelhpi University (Derner Institute)               650.000000          NaN
# Adelhpi University/ C.W. Post                              NaN          NaN
# Adelphi Univ.                                       150.000000     4.500000
# Adelphi University                                  247.702128     4.327586
# Adler                                               157.000000          NaN
# Adler School Of Professional Psychology             306.500000     4.500000
# Adler School Of Professional Psychology/Adler U...  151.000000     5.500000
# Adler University                                    155.000000     4.000000
# Adler University (Chicago)                                 NaN          NaN
# Adler University (Vancouver)                               NaN          NaN
# Adler University, Vancouver                         151.000000     4.000000
# ...                                                        ...          ...
# Wycliffe College                                           NaN          NaN
# Wycliffe College At University Of Toronto           163.000000     5.000000
# Wyoming                                                    NaN          NaN
# Wyoming University                                         NaN          NaN
# Xavier University                                   152.300000     4.277778
# Xiamen University                                          NaN          NaN
# Xxxx University                                            NaN          NaN
# Xxxxxxx University                                         NaN          NaN
# Yale Uni                                                   NaN          NaN
# Yale Univ                                           800.000000     3.500000
# Yale University                                     401.937808     4.587461
# Yalel Academy                                              NaN          NaN
# Yanshan University                                         NaN          NaN
# Yeshiva University                                  301.707317     4.679487
# Yildiz Technical University                         167.000000     5.000000
# Yokohama National University                               NaN          NaN
# Yonsei University                                          NaN          NaN
# York Univ. (Toronto)                                       NaN          NaN
# York University                                     385.616000     4.491453
# York Univetsit                                             NaN          NaN
# Youngstown State University                         700.000000     5.500000
# Yuan Ze University                                         NaN          NaN
# ZIBI Graduate School Berlin                                NaN          NaN
# Zarif University                                           NaN          NaN
# Zhejiang University                                        NaN          NaN
# Zhejiang University Of Technology                   150.000000     3.000000
# Zhengzhou University                                160.000000     4.000000
# Zurich Graduate School In Mathematics                      NaN          NaN
# Zurich Life Sciences                                790.000000     3.500000
# Zurich School Of Economics                                 NaN          NaN
#
#                                                     gre_subject  \
# uni_name
# A.T. Still University                                       NaN
# AA School Of Architecture                                   NaN
# AAUW Fellowship                                             NaN
# ADH Geneva Academy Of International Humanitaria...          NaN
# ALL                                                         NaN
# ALL University                                              NaN
# AMNH Richard Gilder Graduate School                         NaN
# ARIZONA STATE UNIV                                          NaN
# ASEE SMART                                                  NaN
# AT&T Labs Fellowship Program (ALFP)                         NaN
# Aalto University                                            NaN
# Aarhus School Of Architecture                               NaN
# Abdus Salam International Centre for Theoretica...          NaN
# Aberystwyth University                                      NaN
# Abilene Christian                                           NaN
# Abilene Christian University                                NaN
# Acadia                                                      NaN
# Acadia University                                           NaN
# Addis Ababa University                                      NaN
# Adelhpi University (Derner Institute)                790.000000
# Adelhpi University/ C.W. Post                               NaN
# Adelphi Univ.                                               NaN
# Adelphi University                                   744.615385
# Adler                                                       NaN
# Adler School Of Professional Psychology              704.000000
# Adler School Of Professional Psychology/Adler U...          NaN
# Adler University                                     760.000000
# Adler University (Chicago)                                  NaN
# Adler University (Vancouver)                                NaN
# Adler University, Vancouver                                 NaN
# ...                                                         ...
# Wycliffe College                                            NaN
# Wycliffe College At University Of Toronto                   NaN
# Wyoming                                                     NaN
# Wyoming University                                          NaN
# Xavier University                                    716.666667
# Xiamen University                                           NaN
# Xxxx University                                             NaN
# Xxxxxxx University                                          NaN
# Yale Uni                                                    NaN
# Yale Univ                                                   NaN
# Yale University                                      806.479592
# Yalel Academy                                               NaN
# Yanshan University                                          NaN
# Yeshiva University                                   737.096774
# Yildiz Technical University                                 NaN
# Yokohama National University                                NaN
# Yonsei University                                           NaN
# York Univ. (Toronto)                                        NaN
# York University                                      718.750000
# York Univetsit                                              NaN
# Youngstown State University                                 NaN
# Yuan Ze University                                          NaN
# ZIBI Graduate School Berlin                                 NaN
# Zarif University                                            NaN
# Zhejiang University                                         NaN
# Zhejiang University Of Technology                           NaN
# Zhengzhou University                                        NaN
# Zurich Graduate School In Mathematics                       NaN
# Zurich Life Sciences                                        NaN
# Zurich School Of Economics                                  NaN
#
#                                                     post_timestamp
# uni_name
# A.T. Still University                                 1.402651e+09
# AA School Of Architecture                             1.331611e+09
# AAUW Fellowship                                       1.335845e+09
# ADH Geneva Academy Of International Humanitaria...    1.301976e+09
# ALL                                                   1.303963e+09
# ALL University                                        1.297314e+09
# AMNH Richard Gilder Graduate School                   1.424363e+09
# ARIZONA STATE UNIV                                    1.392008e+09
# ASEE SMART                                            1.325263e+09
# AT&T Labs Fellowship Program (ALFP)                   1.266901e+09
# Aalto University                                      1.368994e+09
# Aarhus School Of Architecture                         1.366171e+09
# Abdus Salam International Centre for Theoretica...    1.425874e+09
# Aberystwyth University                                1.371011e+09
# Abilene Christian                                     1.383913e+09
# Abilene Christian University                          1.383628e+09
# Acadia                                                1.425532e+09
# Acadia University                                     1.236229e+09
# Addis Ababa University                                1.334290e+09
# Adelhpi University (Derner Institute)                 1.329627e+09
# Adelhpi University/ C.W. Post                         1.331698e+09
# Adelphi Univ.                                         1.312379e+09
# Adelphi University                                    1.361296e+09
# Adler                                                 1.392959e+09
# Adler School Of Professional Psychology               1.361893e+09
# Adler School Of Professional Psychology/Adler U...    1.425013e+09
# Adler University                                      1.424344e+09
# Adler University (Chicago)                            1.424236e+09
# Adler University (Vancouver)                          1.427947e+09
# Adler University, Vancouver                           1.425791e+09
# ...                                                            ...
# Wycliffe College                                      1.393218e+09
# Wycliffe College At University Of Toronto             1.425359e+09
# Wyoming                                               1.377234e+09
# Wyoming University                                    1.395029e+09
# Xavier University                                     1.391275e+09
# Xiamen University                                     1.298956e+09
# Xxxx University                                       1.412654e+09
# Xxxxxxx University                                    1.412741e+09
# Yale Uni                                              1.421298e+09
# Yale Univ                                             1.389416e+09
# Yale University                                       1.300414e+09
# Yalel Academy                                         1.268456e+09
# Yanshan University                                    1.322456e+09
# Yeshiva University                                    1.351937e+09
# Yildiz Technical University                           1.391663e+09
# Yokohama National University                          1.268543e+09
# Yonsei University                                     1.167109e+09
# York Univ. (Toronto)                                  1.300680e+09
# York University                                       1.334961e+09
# York Univetsit                                        1.426824e+09
# Youngstown State University                           1.331051e+09
# Yuan Ze University                                    1.174018e+09
# ZIBI Graduate School Berlin                           1.356671e+09
# Zarif University                                      1.359695e+09
# Zhejiang University                                   1.250831e+09
# Zhejiang University Of Technology                     1.363061e+09
# Zhengzhou University                                  1.367381e+09
# Zurich Graduate School In Mathematics                 1.402376e+09
# Zurich Life Sciences                                  1.292173e+09
# Zurich School Of Economics                            1.361509e+09
#
# [4535 rows x 8 columns]

# %%
gre.groupby(by="uni_name")[["row_id"]].count() > 100
# Out:
#                                                     row_id
# uni_name
# A.T. Still University                                False
# AA School Of Architecture                            False
# AAUW Fellowship                                      False
# ADH Geneva Academy Of International Humanitaria...   False
# ALL                                                  False
# ALL University                                       False
# AMNH Richard Gilder Graduate School                  False
# ARIZONA STATE UNIV                                   False
# ASEE SMART                                           False
# AT&T Labs Fellowship Program (ALFP)                  False
# Aalto University                                     False
# Aarhus School Of Architecture                        False
# Abdus Salam International Centre for Theoretica...   False
# Aberystwyth University                               False
# Abilene Christian                                    False
# Abilene Christian University                         False
# Acadia                                               False
# Acadia University                                    False
# Addis Ababa University                               False
# Adelhpi University (Derner Institute)                False
# Adelhpi University/ C.W. Post                        False
# Adelphi Univ.                                        False
# Adelphi University                                    True
# Adler                                                False
# Adler School Of Professional Psychology              False
# Adler School Of Professional Psychology/Adler U...   False
# Adler University                                     False
# Adler University (Chicago)                           False
# Adler University (Vancouver)                         False
# Adler University, Vancouver                          False
# ...                                                    ...
# Wycliffe College                                     False
# Wycliffe College At University Of Toronto            False
# Wyoming                                              False
# Wyoming University                                   False
# Xavier University                                    False
# Xiamen University                                    False
# Xxxx University                                      False
# Xxxxxxx University                                   False
# Yale Uni                                             False
# Yale Univ                                            False
# Yale University                                       True
# Yalel Academy                                        False
# Yanshan University                                   False
# Yeshiva University                                    True
# Yildiz Technical University                          False
# Yokohama National University                         False
# Yonsei University                                    False
# York Univ. (Toronto)                                 False
# York University                                       True
# York Univetsit                                       False
# Youngstown State University                          False
# Yuan Ze University                                   False
# ZIBI Graduate School Berlin                          False
# Zarif University                                     False
# Zhejiang University                                  False
# Zhejiang University Of Technology                    False
# Zhengzhou University                                 False
# Zurich Graduate School In Mathematics                False
# Zurich Life Sciences                                 False
# Zurich School Of Economics                           False
#
# [4535 rows x 1 columns]

# %% [markdown]
# ## box plot goodness
# We saw box plots in lab 2, but never got to use them on anything but simulated data. Now is our opportunity! (For information on the meaning of box plots, see lab 2.)

# %%
fig, axes = plt.subplots()
gre['ugrad_gpa'].plot.box(ax=axes)
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
gre[["ugrad_gpa"]] <= 4
# Out:
#         ugrad_gpa
# 0           False
# 1           False
# 2           False
# 3            True
# 4           False
# 5           False
# 6           False
# 7           False
# 8            True
# 9           False
# 10          False
# 11           True
# 12           True
# 13           True
# 14           True
# 15          False
# 16           True
# 17          False
# 18          False
# 19          False
# 20           True
# 21          False
# 22          False
# 23           True
# 24          False
# 25           True
# 26           True
# 27           True
# 28          False
# 29          False
# ...           ...
# 345273      False
# 345274      False
# 345275      False
# 345276      False
# 345277      False
# 345278      False
# 345279      False
# 345280      False
# 345281      False
# 345282      False
# 345283      False
# 345284      False
# 345285      False
# 345286      False
# 345287      False
# 345288      False
# 345289      False
# 345290      False
# 345291      False
# 345292      False
# 345293      False
# 345294      False
# 345295      False
# 345296      False
# 345297      False
# 345298      False
# 345299      False
# 345300      False
# 345301      False
# 345302      False
#
# [345303 rows x 1 columns]

# %%
fig, axes = plt.subplots()
gre["ugrad_gpa"][gre["ugrad_gpa"] <= 4].plot.box(ax=axes)
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
# other things to do: do a time series, look at gpa over time, etc.

# %% [markdown]
# # Let's compare stuff
# ## Ye olde scatter plot

# %% [markdown]
# pick two columns want to plot as x and y

# %%
fig, axes = plt.subplots()
gre.plot.scatter(x="ugrad_gpa", y="gre_verbal", ax=axes)
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %% [markdown]
# Ugh, something is not right in Denmark, my friend.
#
# What's wrong here? What can we do?

# %%
gre_old = gre[gre["is_new_gre"] == 0]

# %%
gre_old.describe()
# Out:
#               row_id  decision_timestamp     ugrad_gpa    gre_verbal  \
# count   23752.000000        2.373800e+04  21464.000000  23752.000000
# mean   190658.954278        1.310356e+09      3.688248    625.902661
# std     67206.233813        3.465979e+07      0.460795    108.344190
# min       394.000000        1.232946e+09      0.250000    200.000000
# 25%    148865.250000        1.295240e+09      3.500000    560.000000
# 50%    177108.000000        1.300766e+09      3.720000    640.000000
# 75%    214663.500000        1.330578e+09      3.890000    700.000000
# max    344056.000000        1.438920e+09      9.990000    800.000000
#
#          gre_quant   gre_writing  gre_subject  post_timestamp
# count  23752.00000  22341.000000  3690.000000    2.375200e+04
# mean     726.99899      4.352334   771.054201    1.310677e+09
# std       91.43371      0.876987   117.246117    3.465051e+07
# min      200.00000      1.500000   200.000000    1.263272e+09
# 25%      687.50000      3.500000   690.000000    1.295845e+09
# 50%      760.00000      4.500000   770.000000    1.300939e+09
# 75%      800.00000      5.000000   860.000000    1.330837e+09
# max      800.00000      6.000000   990.000000    1.438920e+09

# %%
fig, axes = plt.subplots()
gre_old.plot.scatter(x="ugrad_gpa", y="gre_verbal", ax=axes)
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
gre_new = gre[gre["is_new_gre"] == 1]

# %%
gre_new.describe()
# Out:
#               row_id  decision_timestamp     ugrad_gpa    gre_verbal  \
# count   56775.000000        5.676000e+04  50903.000000  56775.000000
# mean   124392.208085        1.390734e+09      3.682248    158.508727
# std    107134.398229        6.006768e+07      0.440743      6.957087
# min         3.000000        1.295154e+09      0.330000    130.000000
# 25%     41331.500000        1.362632e+09      3.500000    154.000000
# 50%     86368.000000        1.393391e+09      3.720000    159.000000
# 75%    153264.000000        1.423544e+09      3.890000    164.000000
# max    341809.000000        1.360119e+10      9.990000    170.000000
#
#           gre_quant   gre_writing  gre_subject  post_timestamp
# count  56775.000000  55008.000000  7164.000000    5.677500e+04
# mean     160.391898      4.238443   786.328867    1.390783e+09
# std        7.144025      0.791338   122.866349    3.130407e+07
# min      130.000000      0.300000   310.000000    1.321938e+09
# 25%      155.000000      3.500000   700.000000    1.362805e+09
# 50%      161.000000      4.000000   790.000000    1.393564e+09
# 75%      166.000000      5.000000   880.000000    1.423717e+09
# max      170.000000      6.000000   990.000000    1.447823e+09

# %%
fig, axes = plt.subplots()
gre_new.plot.scatter(x="ugrad_gpa", y="gre_verbal", ax=axes)
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
gre_new_accepted = gre_new[gre_new["decision"] == "Accepted"]

# %%
gre_new_accepted.describe()
# Out:
#               row_id  decision_timestamp     ugrad_gpa    gre_verbal  \
# count   27992.000000        2.798500e+04  25342.000000  27992.000000
# mean   120606.154473        1.390786e+09      3.694221    158.778115
# std    104598.480159        7.938153e+07      0.430629      6.782043
# min         3.000000        1.296968e+09      0.330000    130.000000
# 25%     40051.500000        1.362546e+09      3.510000    154.000000
# 50%     84911.000000        1.393391e+09      3.740000    159.000000
# 75%    147022.250000        1.423544e+09      3.900000    164.000000
# max    341794.000000        1.360119e+10      9.990000    170.000000
#
#           gre_quant   gre_writing  gre_subject  post_timestamp
# count  27992.000000  27078.000000  3262.000000    2.799200e+04
# mean     160.481495      4.275593   799.481913    1.390681e+09
# std        7.109414      0.780237   121.321589    3.117920e+07
# min      130.000000      0.300000   310.000000    1.321938e+09
# 25%      155.000000      4.000000   710.000000    1.362719e+09
# 50%      162.000000      4.000000   810.000000    1.393564e+09
# 75%      167.000000      5.000000   890.000000    1.423717e+09
# max      170.000000      6.000000   990.000000    1.447736e+09

# %%
fig, axes = plt.subplots()
gre_new_accepted.plot.scatter(x="ugrad_gpa", y="gre_verbal", ax=axes)
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %% [markdown]
# ## how deal with weirdo gpas > 4?

# %%
gre_new["ugrad_gpa"] <= 4
# Out:
# 3          True
# 8          True
# 11         True
# 12         True
# 13         True
# 14         True
# 16         True
# 20         True
# 23         True
# 24        False
# 25         True
# 26         True
# 27         True
# 28        False
# 29        False
# 30        False
# 33         True
# 34         True
# 35         True
# 36         True
# 44         True
# 45        False
# 46        False
# 48         True
# 49         True
# 52         True
# 53         True
# 57         True
# 59         True
# 62         True
#           ...
# 341618     True
# 341632     True
# 341633     True
# 341634     True
# 341636     True
# 341638     True
# 341640     True
# 341646     True
# 341652     True
# 341655     True
# 341672     True
# 341679     True
# 341682     True
# 341686     True
# 341687     True
# 341688     True
# 341691     True
# 341696     True
# 341719     True
# 341725     True
# 341732     True
# 341733     True
# 341743     True
# 341756     True
# 341766     True
# 341782     True
# 341784     True
# 341786     True
# 341794     True
# 341809     True
# Name: ugrad_gpa, Length: 56775, dtype: bool

# %%
gre_new_normal_gpa = gre_new[gre_new["ugrad_gpa"] <= 4]

# %%
fig, axes = plt.subplots()
gre_new_normal_gpa.plot.scatter(x="ugrad_gpa", y="gre_verbal", ax=axes)
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %% [markdown]
# Not too promising....
#
# Let's explore *lots* of different potential relations at once.

# %%
from pandas.plotting import scatter_matrix

# %%
gre_new_just_scores = gre_new_normal_gpa[[
    'ugrad_gpa', 'gre_verbal', "gre_quant", "gre_writing"
]]

# %%
scatter_matrix(
    gre_new_just_scores,
    alpha=0.2,
    figsize=(6, 6),
    diagonal='kde'
)
# Out:
# <img src="data:image/png;base64,..." width="599.4444603242996">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1323b6d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12eb1c7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fc12908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fc557b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11fca1ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120f177f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12ea85908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12ead0390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12ebdf898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12edc5c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12ee17240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1308a4c18>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1308f6128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a0b7ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1309586a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13154a198>]], dtype=object)
