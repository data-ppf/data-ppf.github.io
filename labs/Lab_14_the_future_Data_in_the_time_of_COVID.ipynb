# %% [markdown]
# # Data: Past, Present, Future
# ## Lab 14 (the final lab!) near-term future & recent past of state surveilance in the public interest

# %% [markdown]
# # Precognition
#
# [minority-report](https://www.youtube.com/watch?v=arACDYMiNuI)
#
# > I'm
# sure you all understand the legalistic
# drawback to pre-crime methodology
#
# >here
# we go again
#
# >look I'm not with the ACLU
# on this Jeff
#
# > well let's not kid ourselves we are
# arresting individuals who have broken no
# law but they will
#
# >the commission of the
# crime itself is absolute metaphysics the
# precogs see the future and they're never
# wrong
#
# > but it's not the future if you
# stop isn't that a fundamental paradox?
#
# # power and principles
#
# ## how did new capabilities rearrange power?
#
# ### who can now do what, from what, to whom?
#
# ## role of rights, harms, justice?

# %% [markdown]
# ## Key questions for our course
#
# What does it mean to be a more "informed public" in matters concerning large scale automated decision making systems? How should proxies for the public--journalists, lawmakers, judges, ethicists, coders--advocate for better public knowledge and better institutions capable of undertaking technical work often inaccessible to the public?
#
# What concepts? What false dichotomies? What errors in thought?
#
# And as ever when thinking about an error in thought:  *cui bono*, *who benefits*?
#
# Lots of actors in this space have lots of reasons for us all to think poorly.
#
# Our job is not to do so.

# %% [markdown]
# # Covid and the contract tracing: techno-surveillance-solutionism
#
# - Contract tracing = "the identification and follow-up of persons who may have come into contact with a person infected with a contagious disease, to help the contacts to get relevant care and treatment." (World Health Organization)
#
# ## Israel example: full force of modern surveillance powers
#
# Israeli gov't order internal security service (Shin Bet) to draw on full range of telecommunication data to undertake contact tracing.
#
# > Emergency Regulations (Location Data), 5780-2020. The regulations permit the collection, processing and use of “technological data” of persons who have contracted the new corona virus (hereinafter: the virus), in order to combat the spread of the corona epidemic
#
# Israeli Supreme court consider many issues around this change of state power:
#
# >Can  the  Israel  Security  Agency  be  granted  authority  to  act  in  areas  that  do  not concern state security by virtue of sec. 7(b)(6) of the Israel Security Agency Law, 5762-2002?
#
# and
#
# >Does  sec.  39(d)  of Basic  Law  The  Government,  which  states:  “Emergency regulations may not [...] infringement upon human dignity”, impose an absolute restriction upon violating  the  right  to  human  dignity,  or  is  such  a  violation  subject  to  the  conditions  established under sec. 12 of Basic Law: Human Dignity and Liberty? (source)[https://versa.cardozo.yu.edu/sites/default/files/upload/opinions/Ben%20Meir%20v.%20Prime%20Minister.pdf]
#
# - temporary injunction
#
# ## India example:
#
# > An analysis by The Times found that the Quarantine Watch app, which is available on Google Android, lacked common security measures, and that the Android version of the Aarogya Setu app leaked a user’s latitude and longitude to a YouTube server.
#
# - "[A Scramble for Virus Apps That Do No Harm](https://www.nytimes.com/2020/04/29/business/coronavirus-cellphone-apps-contact-tracing.html?auth=login-email&login=email)", Jennifer Valentino-DeVries, Natasha Singer and Aaron Krolik; NYT, Apr 29 2020
#
# ## Global initiative to attempt to create technological solutions GIVEN the many concerns about privacy and surveillance we have discussed
# 	- how to minimize amount of information given to government or corporations
# 	- how to prevent third-parties from identifying people
# 	- how appropriately balance need for anonymity and need for identification
#
# ##Apple-Google Covid tracing API
#
#
# ![covid-tracing_1](https://9to5google.com/wp-content/uploads/sites/4/2020/04/google-apple-covid-19-tracing-1.jpg)
#
# - new special-purpose private key each day, known as a “temporary exposure key” created in phone.
#
# - This key generates random identification numbers called “rolling proximity identifiers” (RPIDs), which change every 10-15 minutes.
#
# - Each phone saves all of its temporary exposure keys
#
# - log all the RPIDs it comes into contact with, for the past 2 weeks.
#
#
# ![covid-tracing_2](https://9to5google.com/wp-content/uploads/sites/4/2020/04/google-apple-covid-19-tracing-2.jpg)
#
#
# [Source](https://www.blog.google/documents/66/Overview_of_COVID-19_Contact_Tracing_Using_BLE_1.pdf)
#
#
# List of major contract tracing initiatives:
# https://docs.google.com/document/d/16Kh4_Q_tmyRh0-v452wiul9oQAiTRj8AdZ5vcOJum9Y/edit?usp=sharing
#
# ## Google-Apple API
#
# - build new *capabilities* into phone (iOS or Android)
#
# > Affected User: When a user is diagnosed as positive, their Temporary Exposure Keys should be shared with other users to alert them to potential exposure. These Temporary Exposure Keys are retrieved using `ENSelfExposureInfoRequest`.
#
# > Exposed User Given a set of Temporary Exposure Keys that indicate a positive diagnosis, the framework allows you to determine whether those Temporary Exposure Keys were observed locally by the user. If so, additional information such as date and duration may also be retrieved using `ENExposureDetectionFinishHandler`.
#
#
# ## Example Implementation
#
# Can find an [example implementation in python](https://github.com/gretelai/contact-tracing-experiment)
#
# >Simple implementation of the Apple + Google contact tracing specification
#
# >This simulation runs a series of mock "proximity interactions" between a single subject and a collection of other handsets that belong to family, friends, coworkers, and other random people.
#
# >At the end, this single subject will report a positive test result, which will trigger all of the other handsets to determine if they were within proximity to the subject's handset, and if so, at which time intervals.
#
# ### implementation notes
#
# - uses [Crypto.Cipher](https://pycryptodome.readthedocs.io/en/latest/src/cipher/cipher.html) module heavily
#
# - uses [Advanced Encryption Standard](https://en.wikipedia.org/wiki/Advanced_Encryption_Standard), 2001
# 	+ line [45](https://github.com/gretelai/contact-tracing-experiment/blob/4b4fa0af57d0cea78ef1604a357b52c658d15e33/handset.py#L45) of `handset.py`
#
# - uses [HKDF](https://tools.ietf.org/html/rfc5869) for cryptographic hash key generation
# 	+ line [36](https://github.com/gretelai/contact-tracing-experiment/blob/4b4fa0af57d0cea78ef1604a357b52c658d15e33/handset.py#L36) of `handset.py`:
# 	+ from [2010](https://eprint.iacr.org/2010/264.pdf), IBM
#
#
#
# - these lines should remind you of our [WWII lab!](https://render.githubusercontent.com/view/ipynb?commit=bd559744b3b592d02bcfdb34371b86f13f329fff&enc_url=&nwo=data-ppf%2Fdata-ppf.github.io&path=labs%2FLab07-2020-Bletchley.ipynb&repository_id=73956715&repository_type=Repository#Basic-Crypto:-Vigen%C3%A8re-cypher)
#
# - then finds set intersection
# 	+ line [128](https://github.com/gretelai/contact-tracing-experiment/blob/4b4fa0af57d0cea78ef1604a357b52c658d15e33/handset.py#L128) of `handset.py` does the matching
#
# ### code output
#
# ``` git clone https://github.com/greteglai/contact-tracing-experiment.git
#
# cd contact-tracing-experiment/
#
# carr2n:'do the work'{contact-tracing-experiment}125: pip3 install -r requirements.txt
#
# carr2n:'do the work'{contact-tracing-experiment}126: py3 life.py
#
# carr2n:'do the work'{contact-tracing-experiment}127: cat report.txt
#
# Simulation Start Time: 2020-04-13T07:00:00
#
#
# Family Count: 7
#
# Friend Count: 19
#
# Coworker Count: 28
#
# Other Count: 46
# ```
#
#
# And then the "triggered" other handsets are listed, some with intense interaction:
#
# ```Handset ID: ad34eecbb25e4a2f9598457c9789975a
#
# Relation to subject: family [SIMULATION DATA ONLY, would not be revealed real-world]
#
# Contact periods:
#
# 		2020-04-13T08:00:00
#
# 		2020-04-14T08:00:00
#
# 		2020-04-14T09:00:00
#
# 		2020-04-16T18:00:00
#
# 		2020-04-17T18:00:00
#
# 		2020-04-20T08:00:00
#
# 		2020-04-20T09:00:00
#
# 		2020-04-21T18:00:00
#
# 		2020-04-23T08:00:00
#
# 		2020-04-26T08:00:00
#
# 		2020-04-26T14:00:00
#
# --------------------
# ```
#
# others with much fewer contacts:
#
# ```Handset ID: d2e72c7654a344a2abca2f4813c6e5a3
#
# Relation to subject: coworker [SIMULATION DATA ONLY, would not be revealed real-world]
#
# Contact periods:
#
# 		2020-04-13T12:00:00
#
# 		2020-04-13T15:00:00
#
# 		2020-04-14T14:00:00
#
# 		2020-04-17T12:00:00
#
# 		2020-04-20T13:00:00
#
# 		2020-04-22T11:00:00
# ```
# as well as the rare contacts:
#
# ```Handset ID: e82c440d181e4056a210ed3021ac9b70
#
# Relation to subject: other [SIMULATION DATA ONLY, would not be revealed real-world]
#
# Contact periods:
#
# 		2020-04-17T10:00:00
# ```
#
#
# For this to be functional, all the other handsets would need to be acquiring all the temporary keys deemed to be infected.
#
#
#
#
# From an epidemiological standpoint, this is most interesting at scale, when you get all the contacts of all the contrats, ad infinitum.
#
# Tension between state/medical knowledge and personal privacy.

# %% [markdown]
# ### "Only" an API
#
# Apple and Google building *capabilities* into their phones.
#
#
# Eliminate major limitations on bluetooth signaling on iOS and provide consistent approach for all developers
#
# Specification [here](https://covid19-static.cdn-apple.com/applications/covid19/current/static/contact-tracing/pdf/ExposureNotification-FrameworkDocumentationv1.2.pdf)
#
# Up to *developers* and *governments* to make use of them.
#
#
# ## so what do we ask in this class?
#
# ### how did new capabilities rearrange power?
#
# #### who can now do what, from what, to whom?
#
#
#
# *Opt-in*: idea is that users *have* to *choose* to use capability
# but.... cell carriers, governments *may* be able to require the use of this capacity.
#
#
#
# ## Contrast: Singapore's *TraceTogether*
# ![grafix](https://www.tracetogether.gov.sg/img/landing-illustration.svg)
#
# - *centralized government server* receives more information (but not location data)
# - Exposed user grants government permission to unveil all contacts with exposed user
#   - illegal not to help government if exposed
#       >" When a person is contacted by MOH, he/she is required by law to assist in the activity mapping of their movements and interactions, and may be asked to provide any information within his/her knowledge or produce any document or record in his/her possession. This includes location timelines and logs in physical or digital form, including data collected and stored by other popular apps in your phone." [source](https://tracetogether.zendesk.com/hc/en-sg/articles/360044860414-Can-I-say-no-to-uploading-my-TraceTogether-data-when-contacted-by-the-Ministry-of-Health-)

# %% [markdown]
# ## COVID surveillance more broadly
#
# >The US Department of Health and Human Services has awarded a contract to build a database system, HHS Protect Now, to track the spread of the coronavirus across the US to the data-mining company Palantir. .... The platform pulls data from across the federal, state, and local governments as well as health care facilities and colleges, and works with the Centers for Disease Control and Prevention and the Federal Emergency Management System. Every night since the system became operational on April 10 the resulting analysis is sent to Dr Deborah Birx,... [source](https://privacyinternational.org/examples/3730/us-hhs-adopts-palantir-platform-nationwide-health-data-mining)
#
# - Palantir, major provider of data mining software to NSA, ICE, FBI, etc.
#
#
#
# https://theintercept.com/document/2017/02/22/palantir-executive-summary/
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## security-privacy tradeoff fallacy
#
# > A decade ago, legal scholar Daniel Solove’s book *Nothing to Hide* compiled the various arguments for why “in times of crisis, we must trade privacy and liberty for greater security” and systematically refuted each one. But not only is the “tradeoffs” position trite; it’s dangerous. *Its real power is not in convincing people to give up liberty for security but in instead framing the response to crisis as a false dilemma in which they have no reasonable choice but to make a sacrifice in return for a solution.* My italics. Jathan Sadowski, "The Authoritarian Trade-Off" https://reallifemag.com/the-authoritarian-trade-off/#
#
#
# - key here: *no reasonable choice* but sacrifice of privacy
#   - assumptions about what technologically necessary
#
# - *cut off inquiry*
#  - privilege
#   - certain kinds of rights over others
#   - certain kinds of harms over others
#   - certain conceptions of the just over others
#
#
#
# ## We've been here before: Response to 9/11
#
# > “You can look at what happened after 9/11,” said James Larus, the dean of the School of Computer and Communications Science at EPFL, a science-focused university in Switzerland. “There were all these consequences for privacy made possible by a crisis.”
#
# - [Op. cit.](https://www.nytimes.com/2020/04/29/business/coronavirus-cellphone-apps-contact-tracing.html?auth=login-email&login=email), NYT Apr 29, 2020
#
# ### Patriot Act and the expansion of US domestic and International Surveillance
#
# - 9/11 allow for an explosion of authorities and re-interpretations

# %% [markdown]
# #"it's just metadata"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Hacking "reasonable expectation of privacy"
#
#
# Supreme Court held that users of telephony have no “reasonable expectation of privacy” in the phone numbers they dial even as they have a reasonable expectation of privacy in the spoken content of their calls.
#
# - Give dialing information willingly to phone company
#
# >“Although petitioner’s conduct may have been calculated to keep the contents of his conversation private, his conduct was not and could not have been calculated to preserve the privacy of the number he dialed.” (Smith v. Maryland, at 743.)
#
#
#
#
#
# Quotation from secret decision with redacted name and date:
# >so “long as no individual has a reasonable expectation of privacy in meta data [sic], the large number of persons whose communications will be subjected to the . . . surveillance is irrelevant to the issue of whether a Fourth Amendment Search or seizure will occur.” (first Collar-Kotelly TR/TT order) p. 63
#
# A later ruling:
#
# >“Put another way, where one individual does not have a Fourth Amendment interest, grouping together a large number of similarly-situated individuals cannot result in the Fourth Amendment interest springing into being ex nihilo.”
#  Amended Memorandum Opinion, 8–9 (Foreign Intelligence Surveillance Court 2013), 8.
#
#  #### Analysis at scale *no different* from analysis of individual
#
#  OR that's what they told the judges
#
#  own history quite different:
#
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Metadata analysis, an example
#
# I'm taking this example from http://kieranhealy.org/blog/archives/2013/06/09/using-metadata-to-find-paul-revere/ and moving it from R to python

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx

# %%
membership_matrix=pd.read_csv("https://raw.githubusercontent.com/kjhealy/revere/master/data/PaulRevereAppD.csv", index_col=[0])

# %%
membership_matrix
# Out:
#                     StAndrewsLodge  LoyalNine  ...  BostonCommittee  LondonEnemies
# Adams.John                       0          0  ...                0              0
# Adams.Samuel                     0          0  ...                1              1
# Allen.Dr                         0          0  ...                0              0
# Appleton.Nathaniel               0          0  ...                1              0
# Ash.Gilbert                      1          0  ...                0              0
# ...                            ...        ...  ...              ...            ...
# Wingfield.William                1          0  ...                0              0
# Winslow.John                     0          0  ...                0              0
# Winthrop.John                    0          0  ...                0              1
# Wyeth.Joshua                     0          0  ...                0              0
# ...

# %% [markdown]
# ##discerning connections!
#
# We are intested in
#
# - who is connected to whom
#
#
# We are going to create an *adjacency matrix*, another square matrix that indicates who is connected to whom.
#
# ###a little more matrix math
# (You are not responsible for this but I want you to know the smoke and mirrors.)
#
# We have to do a little of basic arithmetic with matrices to make this work.
#
# First we need the idea of the transpose, which is just flipping the rows and columns of a matrix.
#
# $\begin{bmatrix}
# 1 & 2  \\
# 3 & 4 \end{bmatrix}^{\mathrm{T}}
# =
# \begin{bmatrix}
# 1 & 3  \\
# 2 & 4 \end{bmatrix}$
#
# The *adjacency* matrix is the product of a matrix and its transpose.
#
# Say we have a $257 * 7$ matrix; its transpose will be $7 * 257$ matrix.
#
# If we multiply an $M * N$ matrix by an $N * M$ matrix, we get a $M * M$ matrix.
#
# So let's start with the adjacency of every person to every other person.
#
# Our goal, then, is a symmetrical matrix that matches 𝑀
# people to 𝑀
#
# people.
#
# In python we can use the .dot method to perform the necessary form of matrix multiplication. We can do this directly on pandas dataframes.

# %%
person_adjacency=membership_matrix.dot(membership_matrix.T)
# multiplying the membership matrix by its transpose

# %%
person_adjacency
# Out:
#                     Adams.John  Adams.Samuel  ...  Wyeth.Joshua  Young.Thomas
# Adams.John                   2             2  ...             0             1
# Adams.Samuel                 2             4  ...             0             2
# Allen.Dr                     1             1  ...             0             1
# Appleton.Nathaniel           1             2  ...             0             2
# Ash.Gilbert                  0             0  ...             0             0
# ...                        ...           ...  ...           ...           ...
# Wingfield.William            0             0  ...             0             0
# Winslow.John                 1             1  ...             0             0
# Winthrop.John                1             2  ...             0             1
# Wyeth.Joshua                 0             0  ...             1             1
# Young.Thomas                 1             2  ...             1             3
#
# [254 rows x 254 columns]

# %% [markdown]
# Now, we can consider this matrix as describing the strength of ties of all the people in it. Let's visualize it.

# %%
H=nx.Graph()

# %%
person_adjacency_names=[person for person in person_adjacency]
for person in person_adjacency:
  for i, j in enumerate(person_adjacency[person]):
    if person != person_adjacency_names[i]:
        H.add_edge(person, person_adjacency_names[i], weight=j)

# %%
nx.draw(H)

# %%
pos=nx.spring_layout(H, iterations=30)
plt.figure(figsize=(40,40))
nx.draw_networkx_edges(H, pos, width=.015)
nx.draw_networkx_nodes(H, pos, node_size=50)
nx.draw_networkx_labels(H, pos)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Graphing the prelude to analysis, not the thing itself
#
# ### Putting data into a graph form, as in `networkx`, allows a wide range of analysis, including sophisticated *supervised* and *unsupervised* learning.
#
# - `Google`'s `Page-Rank`--the core of its search algorithm--is a graph analysis algorithm.
#
# - US GOV sponsor vast research into social network analysis > 2001
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ### If we use a simple value of calculating the centrality of a node in the graph, we end up with ....
#
#
#
#
# Paul Revere.
#
# Would that the British had this intelligence . . . .
#
# Metadata matters....

# %% [markdown]
# ## Casting the PATRIOT act as a *mere update* bc tech has changed
#
# FBI fact sheet:
# >“Section 216 updated the law to the technology. It ensures that law enforcement will be able to collect non-content information about terrorists' communications regardless of the media they use.”
#
# No BFD, civil libertarians. Gotta be done.

# %% [markdown]
# #fallacy of technological determinism
#
# Let's check out this masterpiece
#
# https://www.youtube.com/watch?v=W8r-tXRLazs
#
#
#
#
#
#
# >They took the credit for your second symphony
#
# >re-written by machine and new technology
#
# >and now I understand the problems you can see.
#
# >Oh oh -- I met your children
#
# >oh oh -- what did you tell them+
#
# >video killed the radio star
#
# >video killed the radio star
#
# >pictures came and broke your heart
#
# >we can't rewind we've gone too far --Buggles, 1979
#
#
# #fundamental thesis of "Video Killed the Radio Star"
#
# >In my mind and in my car
#
# >We can't rewind we've gone too far
#
# >Pictures came and broke your heart
#
# >*Put the blame on VTR*
#
# >lest point be lost “radio star” is stuck in a plastic tube from which she cannot escape [1:51]
#
# > VTR = Video Tape Recorder"
#
#
# ##metaphysics of 'Video Killed the Radio Star'
# - agency of technology
# - inevitability
# - outside our control
# - evolution unilinear
# - clear link to normative
#     - technological development means (creative) destruction and downsizing
#     - necessarily so, so accept it
# - overrides *rights* talk or *justice* talk or *power* talk
#
# #technological determinism
#
# - roughly, a belief that technology *causes* social, economic and cultural transformation
#
#   - often belief that technology primary, most important cause of these changes
# often belief that technology has internal dynamic, a univocal path of development
#
# -*belief* in technological determinism itself a major cause
#
#   - even if false (as it surely is), belief in inevitability of technological change a major political and economic argument
#   -need to figure out what to do given the change or, surrender to its (non-extant) inevitability
#
# ## Examples
# - NSA: We simply gotta update our legal authorieez bc tech
# - “Internet Killed the Video Star: How In-House Internet Distribution of Home Video Will Affect Profit”
# - “Video killed the radio star, but has Google killed the learning organization?”

# %% [markdown]
# None of this is *true* but many vested interests in saying it is
#
# - We don't *have* to use algorithmic decision making systems.
#
# - Privacy is not dead bc tech.
#
# - the only way to support journalism or book writing or X is spying on you to serve ads
#
# ## Back to class
#
# Frank Pasquale:
# >"While the first wave of algorithmic accountability focuses on improving existing systems, a second wave of research has asked *whether they should be used at all*—and, if so, who gets to govern them."  https://lpeblog.org/2019/11/25/the-second-wave-of-algorithmic-accountability/
#
# Julia Powles and Helen Nissenbaum:
# >Which systems really deserve to be built? Which problems most need to be tackled? Who is best placed to build them? And who decides? We need genuine accountability mechanisms, external to companies and accessible to populations. Any A.I. system that is integrated into people’s lives must be capable of contest, account, and redress to citizens and representatives of the public interest. https://onezero.medium.com/the-seductive-diversion-of-solving-bias-in-artificial-intelligence-890df5e5ef53
#
# Accountability iff
# - contest
# - account
# - redress
#
#
# # contest, accounting, and redress *require* knowledge of
# - algorithmic forms
# - data, its problems, its pitfalls
# - effects at scale
# - design choices
# - ethics
# - political effects of designed system
#
#
# i. e.
#
# something akin to:

# %% [markdown]
# # our long strange trip
#
# - 2019-01-22: 1 of 14 intro to course
# - 2019-01-29: 2 of 14 setting the stakes
# - 2019-02-05: 3 of 14 risk and social physics
# - 2019-02-12: 4 of 14 statecraft and quantitative racism
# - 2019-02-19: 5 of 14 intelligence, causality, and policy
# - 2019-02-26: 6 of 14 data gets real: mathematical baptism
# - 2019-03-05: 7 of 14 WWII, dawn of digital computation
# - 2019-03-12: 8 of 14 birth and death of AIq
# - 2019-03-26: 9 of 14 big data, old school (1958-1980)
# - 2019-04-02: 10 of 14 data science, 1962-2017
# - 2019-04-09: 11 of 14 AI2.0
# - 2019-04-16: 12 of 14 ethics
# - 2019-04-23: 13 of 14 present problems: attention economy+VC=dumpsterfire
# - 2019-04-30: 14 of 14 future solutions
